# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
#/content/drive/MyDrive/Colab Notebooks/Covid.csv
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Covid.csv")
df.head(50)
# Out:
#     Nucleus  Exosome  Ribosome  Membrane  Endoplasmic Reticulum  Cytosol  \
# 0     0.999    1.000     0.720     0.840                  0.450    0.000
# 1     0.999    1.000     0.737     0.834                  0.492    0.000
# 2     0.999    1.000     0.729     0.831                  0.497    0.000
# 3     0.999    1.000     0.724     0.831                  0.496    0.000
# 4     0.999    1.000     0.644     0.818                  0.271    0.000
# 5     0.998    1.000     0.641     0.805                  0.323    0.000
# 6     0.999    1.000     0.725     0.846                  0.422    0.000
# 7     0.999    1.000     0.722     0.847                  0.432    0.000
# 8     0.999    1.000     0.717     0.842                  0.448    0.000
# 9     0.999    1.000     0.729     0.845                  0.442    0.000
# 10    0.999    1.000     0.729     0.843                  0.455    0.000
# 11    0.999    1.000     0.722     0.840                  0.467    0.000
# ...

# %%
df.keys()
# Out:
# Index(['Nucleus', 'Exosome', 'Ribosome', 'Membrane', 'Endoplasmic Reticulum',
#        'Cytosol', 'Variant'],
#       dtype='object')

# %%
inputs = df.drop('Variant',axis='columns')
target = df.Variant

# %%
df.head()
# Out:
#    Nucleus  Exosome  Ribosome  Membrane  Endoplasmic Reticulum  Cytosol  \
# 0    0.999      1.0     0.720     0.840                  0.450      0.0
# 1    0.999      1.0     0.737     0.834                  0.492      0.0
# 2    0.999      1.0     0.729     0.831                  0.497      0.0
# 3    0.999      1.0     0.724     0.831                  0.496      0.0
# 4    0.999      1.0     0.644     0.818                  0.271      0.0
#
#   Variant
# 0   Alpha
# 1   Alpha
# 2   Alpha
# 3   Alpha
# 4   Alpha

# %%
df.shape
# Out:
# (47, 7)

# %%
inputs.head()
# Out:
#    Nucleus  Exosome  Ribosome  Membrane  Endoplasmic Reticulum  Cytosol
# 0    0.999      1.0     0.720     0.840                  0.450      0.0
# 1    0.999      1.0     0.737     0.834                  0.492      0.0
# 2    0.999      1.0     0.729     0.831                  0.497      0.0
# 3    0.999      1.0     0.724     0.831                  0.496      0.0
# 4    0.999      1.0     0.644     0.818                  0.271      0.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.2)

# %%
len(X_train)
# Out:
# 37

# %%
len(X_test)
# Out:
# 10

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.7

# %%
df.corr()
# Out:
#                         Nucleus   Exosome  Ribosome  Membrane  \
# Nucleus                1.000000  0.528646  0.325975  0.543831
# Exosome                0.528646  1.000000  0.076637  0.880064
# Ribosome               0.325975  0.076637  1.000000  0.361381
# Membrane               0.543831  0.880064  0.361381  1.000000
# Endoplasmic Reticulum -0.019297 -0.012810  0.814965  0.201011
# Cytosol               -0.145317 -0.443183  0.043347 -0.360188
#
#                        Endoplasmic Reticulum   Cytosol
# Nucleus                            -0.019297 -0.145317
# Exosome                            -0.012810 -0.443183
# Ribosome                            0.814965  0.043347
# Membrane                            0.201011 -0.360188
# Endoplasmic Reticulum               1.000000 -0.051391
# Cytosol                            -0.051391  1.000000

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier().fit(X_train, y_train)

print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.70

# %%
inputs.head()
# Out:
#    Nucleus  Exosome  Ribosome  Membrane  Endoplasmic Reticulum  Cytosol
# 0    0.999      1.0     0.720     0.840                  0.450      0.0
# 1    0.999      1.0     0.737     0.834                  0.492      0.0
# 2    0.999      1.0     0.729     0.831                  0.497      0.0
# 3    0.999      1.0     0.724     0.831                  0.496      0.0
# 4    0.999      1.0     0.644     0.818                  0.271      0.0

# %%
model.predict([[0.999,1,0.720,0.840,0.450,0.0]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array(['Alpha'], dtype=object)

# %%
model.predict([[0.980,1,0,0.759	,0,0]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array(['Delta'], dtype=object)

# %%
#From Random Dataset
model.predict([[0.962,1,0,0.645,0.239,0]]) 
#The input accurately predicted for >MH025764.1 Porcine deltacoronavirus strain CH/JXJGS01/P50, complete genome
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array(['Delta'], dtype=object)
